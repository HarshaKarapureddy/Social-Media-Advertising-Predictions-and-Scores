# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
clean_df = pd.read_csv("campaigns_clean.csv")
print("Shape:", clean_df.shape)
display(clean_df.head(3))
clean_df.info()
# Out:
# Shape: (300000, 18)
#    Campaign_ID Target_Audience     Campaign_Goal Channel_Used  \
# 0       529013       Men 35-44    Product Launch    Instagram
# 1       275352     Women 45-60  Market Expansion     Facebook
# 2       692322       Men 45-60    Product Launch    Instagram
#
#    Conversion_Rate   ROI     Location Language  Clicks  Impressions  \
# 0             0.15  5.79    Las Vegas  Spanish     500         3000
# 1             0.01  7.21  Los Angeles   French     500         3000
# 2             0.08  0.43       Austin  Spanish     500         3000
#
#    Engagement_Score Customer_Segment        Date         Company  \
# 0                 7           Health  2022-02-25      Aura Align
# 1                 5             Home  2022-05-12  Hearth Harmony
# 2                 9       Technology  2022-06-19   Cyber Circuit
#
#    Duration_Days  Acquisition_Cost_Num  Month  Season
# 0             15                 500.0      2  Winter
# ...

# %%
num_cols = [
    "Duration_Days",
    "Acquisition_Cost_Num",
    "Clicks",
    "Impressions",
    "Engagement_Score",
    "Conversion_Rate",
    "ROI"
]

# %%
skew_values = clean_df[num_cols].skew().sort_values()
skew_values
# Out:
# Conversion_Rate        -0.000805
# Acquisition_Cost_Num   -0.000519
# Duration_Days           0.000000
# Impressions             0.206032
# Clicks                  0.256214
# Engagement_Score        0.392467
# ROI                     0.415727
# dtype: float64
